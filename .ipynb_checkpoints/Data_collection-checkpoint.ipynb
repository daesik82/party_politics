# %% [markdown]
# # 데이터 수집
# ## 웹스크랩핑
#     경북대 사회과학기초자료연구소 연구방법논총 논문 다운로드
#     대구광역시의회 5분 자유발언
#  ## API
#      네이버 API, 트위터 API

# %% [markdown]
# ## 경북대 사회과학기초자료연구소 연구방법논총에서 논문 다운로드
#     사이트: http://www.basicdata.kr/journals/
#     크롬 검사 기능 활용: 크롬→마우스→오른쪽 클릭→검사

# %%
import wget
url = 'http://www.basicdata.kr/uploads/2018/06/05/04_Lee_2018.pdf'
wget.download(url, '1.pdf')

# %% [markdown]
# ## c.f. 현재 위치

# %%
import os
os.getcwd()

# %%
url = 'http://www.basicdata.kr/uploads/2018/06/05/03_오수경.신창환_2018.pdf'
wget.download(url, '2.pdf')
url = 'http://www.basicdata.kr/uploads/2018/06/05/02_김진원.정한범_2018.pdf'
wget.download(url, '3.pdf')

# %% [markdown]
# ## 대구광역시의회 5분자유발언 수집
#     사이트: https://council.daegu.go.kr/kr/activity/free
#     수집항목: 대수, 회의명, 의원명, 제목, 질문일
#     출처: 경북대학교 김창현

# %%
from bs4 import BeautifulSoup
import requests

i=1
num=range(i,10)

for i in num :
    url = 'https://council.daegu.go.kr/kr/activity/free?reform=list&page={}&flag=&keyword=&search_code=&th_sch=all&th_sch=all&mem_sch=&sess_sch='.format(i)
    req=requests.get(url, verify=False)
    html = req.content
    soup = BeautifulSoup(html, 'html.parser')
    for link in soup.find_all('td'):
        data=link.get_text('td')
        print(data)
    i +=1

# %%
from bs4 import BeautifulSoup
import requests

i=1
num=range(i, 2)
with open('daegu.txt', 'w', encoding='UTF8') as f:
    for i in num:
        url = 'https://council.daegu.go.kr/kr/activity/free?reform=list&page={}&flag=&keyword=&search_code=&th_sch=all&th_sch=all&mem_sch=&sess_sch='.format(i)
        req=requests.get(url, verify=False)
        html = req.content
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('td'):
            data=link.get_text('td')
            print(data)
            f.write(data)
        i +=1

# %%
from bs4 import BeautifulSoup
import requests
import csv

i=1
num=range(i, 2)
with open('daegu.csv', 'w', encoding='UTF8') as f:
    csv_writer=csv.writer(f)
    for i in num:
        url = 'https://council.daegu.go.kr/kr/activity/free?reform=list&page={}&flag=&keyword=&search_code=&th_sch=all&th_sch=all&mem_sch=&sess_sch='.format(i)
        req=requests.get(url, verify=False)
        html = req.content
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('td'):
            data=link.get_text('td')
            csv_writer.writerow([data]) 
        i +=1

# %% [markdown]
# ## 네이버 API를 통한 신문기사 데이터 수집
#     네이버 애플리케이션 등록: https://developers.naver.com/apps/#/register
#     신문기사 검색: 사용 API → 검색

# %%
import requests
import json

with open('naver_config.json') as f:
    tokens = json.loads(f.read())

Client_ID = tokens["Client_ID"]
Client_Secret = tokens["Client_Secret"]

query = '경북대학교'
url = 'https://openapi.naver.com/v1/search/news.json?query={}&display=1'.format(query)
headers = {
    'X-Naver-Client-Id': Client_ID,
    'X-Naver-Client-Secret': Client_Secret,
           }
req = requests.get(url, headers=headers)
# print(req.text)
json_data = json.loads(req.text)
# print(json_data)

for data in json_data['items']:
    print("기사제목: {0}, 기사링크 : {1}, 기사내용: {2}, 기사날짜: {3}".format(data['title'],
                                                                                data['originallink'],
                                                                                data['description'],
                                                                                data['pubDate']))

# %% [markdown]
# ## 트위터 데이터 수집
# ### 트위터 수집 방법
#
#     Real time tweets → Streaming API: tweepy
#     Historical tweets →  Search API (1 week): twittersearch
#     User networks → Followers API
#     Geolocation → Geo API
# https://dev.twitter.com/rest/reference/get/geo/search

# %% [markdown]
# #### c.f. 쥬피터 내부에서 패키지 인스톨

# %%
# !pip3 install TwitterSearch 
import TwitterSearch

# %%
from TwitterSearch import *
import time
import datetime
import json
import csv

# %%
######### Twitter auth 호출 #################
with open('twitter_config.json') as f:
    tokens = json.loads(f.read())
#######################################

# %%
consumer_key = tokens["consumer_key"]
consumer_secret = tokens["consumer_secret"] # DO NOT SHARE WITH ANYONE!
access_token = tokens["access_token"]
access_token_secret = tokens["access_token_secret"]

# %%
file_id = 'korea'
now_date = str(datetime.date.today())

try:
    tso = TwitterSearchOrder() # create a TwitterSearchOrder object
    tso.set_keywords(['한국', '대한민국', '남한'], or_operator=True) # let's define all words we would like to have a look for
    tso.set_language('ko') # we want to see Korean tweets only
    tso.set_include_entities(False) # and don't give us all those entity information
    # tso.set_until(datetime.date(2017, 4, 1))
    # tso.set_since_id(25007592717275955) # id after first collection

    # it's about time to create a TwitterSearch object with our secret tokens
    ts = TwitterSearch(
        consumer_key = consumer_key,
        consumer_secret = consumer_secret,
        access_token = access_token,
        access_token_secret = access_token_secret
    )

     # this is where the fun actually starts :)
    with open('{0}_TwitterSearch_{1}.csv'.format(file_id, now_date), 'w', encoding='utf-8') as saveFile:
        csv_writer = csv.writer(saveFile, delimiter='\t')
        csv_writer.writerow(['tweet_time', 'twitter_id', 'tweet_text'])
        for tweet in ts.search_tweets_iterable(tso):
            #print( '%s tweeted: %s on %s' % ( tweet['user']['id_str'], tweet['text'], tweet['created_at'] ) )
            tweet_time = time.strftime('%Y-%m-%d', time.strptime(tweet['created_at'],'%a %b %d %H:%M:%S +0000 %Y'))
            print(tweet_time)
            twitter_id = tweet['user']['id_str']
            print(twitter_id)
            tweet_text = tweet['text'].replace("\n", "")
            print(tweet_text)
            csv_writer.writerow([tweet_time, twitter_id, tweet_text])
       
except TwitterSearchException as e: # take care of all those ugly errors if there are some
    print(e)
# Out:
# 2018-08-17
# 950313850196209665
# RT @C_F_diablesse: 모든 걸 &lt;입법&gt;의 문제로만 돌리면 한국에 “사법부”가 왜 필요하며, 법관의 “재량”을 존중해야 할 까닭은 무엇이겠습니까? 이번 “안희정 성폭력 사건”은 현행법의 테두리 안에서도 유죄의 인정이 가능했던 사건이었음에도…
# 2018-08-17
# 565416806
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 141585942
# RT @Linco_a: 단백질 히잡이라며 긴머리 잘라내서 탈코하는 것도 결국 남성시선에서 여성성을 부여하는 20-30대 젋은 여성에게나 탈코인거지..(물론 나잇대로 딱 분류할 수 있는 문제는 아님) 예전에도 얘기했는데 한국의 중년 이후 여성의 디폴트…
# 2018-08-17
# 1016064858645618688
# RT @JIN_Ji92: 후... 지민 허리춤에 저거.. 인제 앤써 음원은 캐신나고 행복할거라 이말입니다,,, 한국..컴백..끝내버리겠다는 정국의 말,, 뼈있는 말이다 이겁니다ㅠㅠㅠㅠㅠㅠㅠㅠㅠ♡#FFGroupBTS #MMVAs #iHeartR…
# 2018-08-17
# 1007679628817850369
# RT @kogasa_parang: 이제 외국인들에게 한국은 매일 밤늦게까지 공부를 하고 야식으로 익스트림 스파이시 누들을 한 그릇씩 해치우는 미친 나라로 각인된 듯 (놀랍게도 사실이다) https://t.co/myhTBYipno
# 2018-08-17
# 977900687907479552
# RT @re_d27: 애인님 : 한국 올때 "누가 이런걸 사?" 싶은 괴식 있으면 좀 사와봐.나 : 알았어. https://t.co/o8HOf3zZhH
# 2018-08-17
# 3988597403
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 365778166
# 일간베스트와 워마드는 5ch가 헤이트스피치하는 바람에 2010년대후반에 일본의 급식들이랑 일본의 젊은이들이 안쓰는 틀딱커뮤니티가 되었듯이 혐오하는 바람에 2020년대후반에 한국의 급식들이랑 한국의 젊은이들이 안쓰는 틀딱커뮤니티가 되지를 마라.
# 2018-08-17
# 1022302406103560194
# RT @BBCNewsKorea_u: 냉면: 올여름 냉면 값 큰 폭 상승...정상회담 이후 '평양냉면 열풍' https://t.co/JHNzYmHRze 올여름 한국의 냉면 가격이 대폭 상승한 것으로 나타났다. 4.27 남북정상회담을 전후로 가격이 껑충…
# 2018-08-17
# 821021902059622400
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 1244927058
# RT @lhc21net: 오늘 발표된 한국갤럽 여론조사, 이해찬 후보 (민주당 지지층) 당대표 선호도에서 35%로 압도적 1위! 특히 20대~40대 젋은층에서 가장 많은 지지를 받았고, 수도권, 호남 등 전 지역 모두 1위를 했습니다. 끝까지 최선을…
# 2018-08-17
# 921143556101758976
# RT @akckd0207: I'm gonna pray for Korea - Adahl스웨덴의 대표급 팝듀오이자 CCM 아티스트 Adahl 한국의 분단 현실을 바라보며 위로의 마음으로 기도하며 직접 쓴 곡https://t.co/8N6xRP89…
# 2018-08-17
# 729284258594881538
# RT @un_0513: 다시ㅣ 보는 답 없는 한국... https://t.co/K3FYuPNCKy
# 2018-08-17
# 882634813663870976
# RT @gkk147: #한기총고발한국기독교총연합회(한기총)를 고발합니다!https://t.co/nOxfCHx7BT https://t.co/9tqiaSTocv
# 2018-08-17
# 3286923684
# RT @fuckin_moon: Rt)저 탈한국이 너무 간절해서 독학으로 유학 준비를 하고 있어요. 사실 곧 시험인데 준비한게 하나도 없어서 마지막 기회라 열심히 해야되요.ㅜㅜ 만약에 다음달에 보는 시험 및 면접에 붙게 된다면 아래 것들 추첨해서 한…
# 2018-08-17
# 950313850196209665
# RT @C_F_diablesse: “안희정 성폭력 사건”과 관련, &lt;입법 미비&gt;로 책임을 회피한 1심 판결에 대해 정치권에서 사법부 대상의 비판이 진행. “판례로 바꾼다”라는 게 한국에서 있겠어요, 판사들이 이 모양인데? https://t.c…
# 2018-08-17
# 199222162
# RT @worldwright: RT) 이게 의도적인지 아닌지 모르겠는데, 한국에서는 새로운 용어를 기득권이 전복적으로 사용하는 경우가 많다. 묘하게 교활하다. “강간 사건”이 “미투 사건”이 되더니, “성적 자기결정권”이 보호될 권리가 아니라 피해자…
# 2018-08-17
# 2744408298
# RT @un_0513: 다시ㅣ 보는 답 없는 한국... https://t.co/K3FYuPNCKy
# 2018-08-17
# 147488152
# RT @LeePianoman: 영화공작 의리의 북한얍삽한 남한 남북모두 윗대가리는 개새끼
# 2018-08-17
# 955758700999753728
# RT @imy1009: 한기총의 설립 목적: "한국기독교를 하나로 묶어서 정부나 사회에 한 목소리를 내자" 이는 정부에 반기를 들고자 함이였다~~https://t.co/10CWUqL9FZ#한기총해체 #고발 #신천지 #강제개종 #한기총고발…
# 2018-08-17
# 1015600764826238977
# RT @Kimmyao_love: 1.데뷔 10년차2.리더 경험 다수(양국 포함)3.다방면 활동 경험(라디오,방송,MC 등)4.뛰어난 언어 구사력(한국어 공부 n년차)5.양국(한국)에 대한 높은 애정과 지식미호 아니면 누가 데뷔조 리더해??…
# 2018-08-17
# 902312198264897537
# RT @worldwright: RT) 이게 의도적인지 아닌지 모르겠는데, 한국에서는 새로운 용어를 기득권이 전복적으로 사용하는 경우가 많다. 묘하게 교활하다. “강간 사건”이 “미투 사건”이 되더니, “성적 자기결정권”이 보호될 권리가 아니라 피해자…
# 2018-08-17
# 737573599863701506
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 812120218717696000
# RT @Sielrin_CM: 2018.08.17 업데이트 안내《가을 패치》- 가을이 시작됩니다.- 업데이트는 지역마다 차이가 있으므로 유의해주시기 바랍니다.- 올 해는 대한민국 서버가 개설된 지 4351 년입니다.- 패치 전과 패치 후…
# 2018-08-17
# 833549664284598273
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 932817856726630400
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 615273122
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 763931572370149376
# RT @silviasun1122: 한국이 얼마나 싫었으면 ㅅㅂ직각으로꺾어버리네;;안기준보다운전잘함 https://t.co/4mGwyyY1A4
# 2018-08-17
# 112944962
# @rkbooks11 너무나 제 스타일인데 수원이라 자주 먹을 수가 없어요 ㅠㅠ 한국의 매운맛이 그리우실 때가 넘으셨어요 ...
# 2018-08-17
# 819806151466328064
# RT @berserkertr19: ㄷㅓ러운 한국놈들 1세트부터 전력으로하고 지랄이야 https://t.co/d5PywzzVx9
# 2018-08-17
# 912109233641885696
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 543105155
# RT @rassak: 왜 한국 매체들은 죄다 남성 범죄자의 변명을 헤드라인으로 실어주죠. 홍대 불법촬영 기사에선 "성기를 드러내고 휴게실을 혼자 점령한 남성에게 욱하는 마음에... 반성문도 7차례나 보냈으나..." 같은 변명 안 실어줬을 거 아니에요…
# 2018-08-17
# 822479442417045504
# RT @Vallen_eStory: 17일~19일 열리는 오버워치 월드컵 한국 예선 홍보 + 제 계정 홍보차 RT 이벤트 진행합니다. RT+팔로 해주신 분 중 한분 추첨해서 사진의 오버워치 디바 라이트업 키체인 선물해드립니다. 당발은 19일 넘어가는…
# 2018-08-17
# 861072319808118785
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 845266948187316224
# RT @Sielrin_CM: 2018.08.17 업데이트 안내《가을 패치》- 가을이 시작됩니다.- 업데이트는 지역마다 차이가 있으므로 유의해주시기 바랍니다.- 올 해는 대한민국 서버가 개설된 지 4351 년입니다.- 패치 전과 패치 후…
# 2018-08-17
# 482701893
# RT @newstapa: 대한민국 국회의원은 자기가 받을 월급을 자기가 결정하는 특권을 가지고 있습니다.반면, 영국과 호주는 외부 독립기구가 의원 월급을 정하고, 월급이 깎여도 거부권을 행사할 수 없습니다.2013년 4월 뉴스타파 '국회의원 억…
# 2018-08-17
# 2440989667
# RT @sYhBirrB1SxG7ot: 한국당 “정부, 북한산 석탄 의혹 자료 요구에 무시로 일관” | 조선일보 AMP https://t.co/myXEAx2yYt
# 2018-08-17
# 902499606826672133
# RT @JIN_Ji92: 후... 지민 허리춤에 저거.. 인제 앤써 음원은 캐신나고 행복할거라 이말입니다,,, 한국..컴백..끝내버리겠다는 정국의 말,, 뼈있는 말이다 이겁니다ㅠㅠㅠㅠㅠㅠㅠㅠㅠ♡#FFGroupBTS #MMVAs #iHeartR…
# 2018-08-17
# 868020579860832256
# RT @lhc21net: "이명박·박근혜 정권 10년 동안 대한민국은 역주행 했습니다. 촛불이 그 역주행을 막았습니다. 복지국가, 공정사회, 한반도 평화! 이것은 촛불혁명이 요구하는 우리 당의 의무입니다. 그러기 위해서는 4번, 5번의 연속해서 집권…
# 2018-08-17
# 3031853490
# 한국왔닷
# 2018-08-17
# 931887297414414336
# RT @girin25: 백합러중에 젤 무서운 새끼들...그건 한국 드라마로 백합 착즙하는 새끼들이다...이들은 스스로가 착즙하는 줄도 잘 모르고 한국식뼈테로엔딩나도 계속 백합을 착즙함...모래에서 기름을 짜고 슈루탄으로 남주를 터트릴 놈들...
# 2018-08-17
# 131836015
# @Aster_KR 그때는 제가 한국에 귀국을 하니 그 다음주?
# 2018-08-17
# 2986451816
# 결국 시장원가라는것은없는자들을더 쥐어짜게되는것이지요실질적인 원가상승은발주처의갑질이 더 많은포지션이되기도합니다해서  토목 건설현장에V,E가 필요한이유입니다대한민국의  공공건설공사의설겨시 표준품… https://t.co/u1Fh69ghnr
# 2018-08-17
# 788688800327278592
# RT @muminmeat: 탁하던 한국공기가  갑자기 환해지길래 뭔일이지 했는데 우리 오빠 입국했다✧*.◟(ˊᗨˋ)◞.*✧ 👏👏❤️웰컴 투 한국❤️❤️ 오랜만에 보니까 더 잘생겼어ㅠㅠㅠㅠ엉흐흑 #김동한 #동한 푹쉬어요💕 https://t.co/smN…
# 2018-08-17
# 813748861370040321
# RT @un_0513: 다시ㅣ 보는 답 없는 한국... https://t.co/K3FYuPNCKy
# 2018-08-17
# 2851736838
# RT @lhc21net: "이명박·박근혜 정권 10년 동안 대한민국은 역주행 했습니다. 촛불이 그 역주행을 막았습니다. 복지국가, 공정사회, 한반도 평화! 이것은 촛불혁명이 요구하는 우리 당의 의무입니다. 그러기 위해서는 4번, 5번의 연속해서 집권…
# 2018-08-17
# 2545490318
# RT @hejsommer: 덴마크인 친구가 이 링크 보내주면서 기자가 극단적으로 묘사했다길래 어디가 극단적인지 한국여자로서 지극히 논리적이라 생각한다고 함 BBC News - 'Why I never want babies' https://t.co/y…
# 2018-08-17
# 618130577
# RT @absfabs00: 친구가 가정적일 줄 알았던 남편이 결혼 직후 돌변해서 따졌더니 나 원래 그런 사람 아닌데 너 꼬실려고 그런 척한 거라고 대놓고 말햇다 함생각해보면 공포 괴담급이고 식민지를 대하는 점령국이라 해도 보이기 힘들 정도의 놀라운…
# 2018-08-17
# 2422235954
# RT @LINK8ENTER: 진영의 첫 한국 팬미팅 개최와 올해의 브랜드 남자연기돌 부문 대상 수상을 기념해 팬 여러분들을 위해 작은 선물을 준비했습니다. 자세한 내용은 아래를 참고해주세요. 팬 여러분들 감사합니다#jinyoung_VLIVE_201…
# 2018-08-17
# 715085253170171904
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 885869541691084801
# RT @fuckin_moon: Rt)저 탈한국이 너무 간절해서 독학으로 유학 준비를 하고 있어요. 사실 곧 시험인데 준비한게 하나도 없어서 마지막 기회라 열심히 해야되요.ㅜㅜ 만약에 다음달에 보는 시험 및 면접에 붙게 된다면 아래 것들 추첨해서 한…
# 2018-08-17
# 1026501050667159552
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 1005943068103618560
# RT @un_0513: 다시ㅣ 보는 답 없는 한국... https://t.co/K3FYuPNCKy
# 2018-08-17
# 4673394199
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 444671427
# @khryoung 그럼 저만 그런게 아니군요~ 통신사의 문제일까 아님 제 기계의 문제일까 고민만 하고 있었어요. 일정기간 발신이 없으면 정지될 수도 있군요. 다음에 한국에 들어가서 알아보고 조치를 취해야할… https://t.co/NrJQkNwU73
# 2018-08-17
# 902134105202073601
# @mexicana1 대한민국 선수 분들 금메달 받기위해 열심히 하시다가 다치시면 마음이 정말 아픕니다ㅠㅠ 다치지 마시고 아프지 않으셨으면 하는 바랍니다! 대한민국 화이팅! 대한민국 선수 분들 화이팅!!❤
# 2018-08-17
# 173402571
# RT @yummy2575: @beluga2046 BBC가 대한민국 정부보다 저출산의 이유를 더 잘 알고 있군요.
# 2018-08-17
# 3957541398
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 2833711327
# RT @lhc21net: 오늘 발표된 한국갤럽 여론조사, 이해찬 후보 (민주당 지지층) 당대표 선호도에서 35%로 압도적 1위! 특히 20대~40대 젋은층에서 가장 많은 지지를 받았고, 수도권, 호남 등 전 지역 모두 1위를 했습니다. 끝까지 최선을…
# 2018-08-17
# 719147714622001152
# RT @VsodongV: ㅋㅋㅋ 오늘 한국이 독일 2점 이상으로 앞서면 부산-서울 걸어서 종주함
# 2018-08-17
# 942898241598668800
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 934246625492451328
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 807937934334668801
# RT @hybaaq: 방문진 이사 선임에 자유한국당 김성태 의원 압박이 있었다고 방통위원장 입으로 시인했는데 이거 그냥 둡니까? 일본 땅이 가라앉으면 일본인들 개성공단으로 이주시켜야 한다는 사이비교 교주 증언만으로도 특검을 하고 사람을 구속시킬려고…
# 2018-08-17
# 937202638965186560
# RT @fuckin_moon: Rt)저 탈한국이 너무 간절해서 독학으로 유학 준비를 하고 있어요. 사실 곧 시험인데 준비한게 하나도 없어서 마지막 기회라 열심히 해야되요.ㅜㅜ 만약에 다음달에 보는 시험 및 면접에 붙게 된다면 아래 것들 추첨해서 한…
# 2018-08-17
# 1008165047799910400
# RT @lostBL1: 모두들 BBC 메인기사의 한국 여성 비비탄 뉴스를 읽어라 https://t.co/wJ9Jp8WtgU
# 2018-08-17
# 1014473528320524288
# RT @absfabs00: 친구가 가정적일 줄 알았던 남편이 결혼 직후 돌변해서 따졌더니 나 원래 그런 사람 아닌데 너 꼬실려고 그런 척한 거라고 대놓고 말햇다 함생각해보면 공포 괴담급이고 식민지를 대하는 점령국이라 해도 보이기 힘들 정도의 놀라운…
# 2018-08-17
# 934443947035729920
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 790543108781944833
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 892682727232634884
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 1029903199774240768
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 3326710274
# 엑소 백현 유니폼 한국 M사이즈 양도합니다나 : 미개봉 새상품 유니폼 한국 M사이즈님 : 현금 75000원백현 포카 구마마 한국반 + 25000원백현 포카 카운트다운 + 55000원백현 포카 구… https://t.co/dTLQGVXA8O
# 2018-08-17
# 2837986772
# RT @Carnal__flower: 요즘 랟펨들이 좆나를 강조하기 위해서 흑좆나 이렇게 쓰시던데 다들 그거 인종차별이고 흑인 남성에 대한 페티시화고 실제 그것때문에 흑인 남성들이 자신이 인간이기보다는 그냥 커다란 자지취급받는것이라고 항의하는거 아셨으…
# 2018-08-17
# 810825461471137792
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 985893188320747521
# RT @LINK8ENTER: 진영의 첫 한국 팬미팅 개최와 올해의 브랜드 남자연기돌 부문 대상 수상을 기념해 팬 여러분들을 위해 작은 선물을 준비했습니다. 자세한 내용은 아래를 참고해주세요. 팬 여러분들 감사합니다#jinyoung_VLIVE_201…
# 2018-08-17
# 3275886368
# RT @rassak: 왜 한국 매체들은 죄다 남성 범죄자의 변명을 헤드라인으로 실어주죠. 홍대 불법촬영 기사에선 "성기를 드러내고 휴게실을 혼자 점령한 남성에게 욱하는 마음에... 반성문도 7차례나 보냈으나..." 같은 변명 안 실어줬을 거 아니에요…
# 2018-08-17
# 168437663
# RT @busanHE: 오늘 한국의 말종들 태극기집회를 보고 올린 댓글중 쵝오의 명언(?)"아빠는 태극기 엄마는 엄마부대 아들은 일베 딸은 워마드 즐거운 우리집 ㅋㅋㅋ"
# 2018-08-17
# 2833711327
# RT @lhc21net: "이명박·박근혜 정권 10년 동안 대한민국은 역주행 했습니다. 촛불이 그 역주행을 막았습니다. 복지국가, 공정사회, 한반도 평화! 이것은 촛불혁명이 요구하는 우리 당의 의무입니다. 그러기 위해서는 4번, 5번의 연속해서 집권…
# 2018-08-17
# 803878179601403905
# RT @Ssm_kikero: #천창룡엄벌하기2탄#문재인대통령 #김경수경남지사#상습적 #허위사실유포 #명예훼손#정보통신망법위반#제31번째 #피고발인 #천창룡 #서울중앙지검고발 "문재인 대통령을 지키며,국민이 적폐청산에 앞장섭니다"정의로…
# 2018-08-17
# 969565137156718592
# RT @un_0513: 다시ㅣ 보는 답 없는 한국... https://t.co/K3FYuPNCKy
# 2018-08-17
# 952538104652472325
# RT @fuckin_moon: Rt)저 탈한국이 너무 간절해서 독학으로 유학 준비를 하고 있어요. 사실 곧 시험인데 준비한게 하나도 없어서 마지막 기회라 열심히 해야되요.ㅜㅜ 만약에 다음달에 보는 시험 및 면접에 붙게 된다면 아래 것들 추첨해서 한…
# 2018-08-17
# 857927586965475329
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 2302908702
# RT @geometryofsleep: 미국에 &lt;To catch a predator&gt; 이라는 방송이 있었다. 이게 뭐냐면 “온라인으로 미성년자에게 접근해 섹스하는 성범죄자들”을 잡는 프로. 탐라에 한국남자가 검거되었을 때 영상이 올라와서 하는 말인데…
# 2018-08-17
# 966865195501944832
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 991661597574578177
# RT @girin25: 백합러중에 젤 무서운 새끼들...그건 한국 드라마로 백합 착즙하는 새끼들이다...이들은 스스로가 착즙하는 줄도 잘 모르고 한국식뼈테로엔딩나도 계속 백합을 착즙함...모래에서 기름을 짜고 슈루탄으로 남주를 터트릴 놈들...
# 2018-08-17
# 719822271875952640
# RT @JIN_Ji92: 후... 지민 허리춤에 저거.. 인제 앤써 음원은 캐신나고 행복할거라 이말입니다,,, 한국..컴백..끝내버리겠다는 정국의 말,, 뼈있는 말이다 이겁니다ㅠㅠㅠㅠㅠㅠㅠㅠㅠ♡#FFGroupBTS #MMVAs #iHeartR…
# 2018-08-17
# 955758700999753728
# RT @v7_ic: 한국기독교총연합회(한기총)를 고발합니다!https://t.co/7YyMNd6Sq1 #한기총고발 https://t.co/Ru9qtCBf7B
# 2018-08-17
# 995276208
# RT @Schalom1004: 헌정사상 대한민국 대통령 중에서 이렇게 국정지지도가 높은 대통령을 보았는가.文대통령 국정지지도 60%대 '복원'..지난주보다 2%p 상승 .https://t.co/mDxCchWswa
# 2018-08-17
# 891841474224021504
# RT @wonnney: 솔직히 헛발질로 말하면 안철수야 말로 한국 정치계 역대급 헛발질러지.. ㅋ
# 2018-08-17
# 817188633979457541
# RT @DanYeol_cos: 한국날씨 현재 상황 https://t.co/6X3JTdHK9s
# 2018-08-17
# 2545490318
# RT @Sielrin_CM: 2018.08.17 업데이트 안내《가을 패치》- 가을이 시작됩니다.- 업데이트는 지역마다 차이가 있으므로 유의해주시기 바랍니다.- 올 해는 대한민국 서버가 개설된 지 4351 년입니다.- 패치 전과 패치 후…
# 2018-08-17
# 2870851290
# RT @kogasa_parang: 이제 외국인들에게 한국은 매일 밤늦게까지 공부를 하고 야식으로 익스트림 스파이시 누들을 한 그릇씩 해치우는 미친 나라로 각인된 듯 (놀랍게도 사실이다) https://t.co/myhTBYipno
# 2018-08-17
# 2198883312
# RT @beluga2046: 지금 BBC 라디오에서 '세계 1위의 저출산률 국가인 한국'에 대한 방송이 나오고 있다. 원인은 1) 임신하고 아이를 가진 여사원에 대한 회사의 퇴사 압력 2) 아이 돌보는 사회적 인프라 부족 3) 아이 한명 키우는데 시…
# 2018-08-17
# 977089557425397760
# RT @_2mong: 한국남자는 가만히 앉아있으면 여자들이 9첩 밥상을 차려오고, 집가서 엄마 밥줘 한다는 걸 정확히 이해하다니 여윽시 한국 항공사 진에어 ~ https://t.co/aeoUw57d6m
# 2018-08-17
# 896943989777092608
# RT @absfabs00: 친구가 가정적일 줄 알았던 남편이 결혼 직후 돌변해서 따졌더니 나 원래 그런 사람 아닌데 너 꼬실려고 그런 척한 거라고 대놓고 말햇다 함생각해보면 공포 괴담급이고 식민지를 대하는 점령국이라 해도 보이기 힘들 정도의 놀라운…
# 2018-08-17
# 1635430814
# RT @C_F_diablesse: 제가 왜 수년전부터 &lt;방청연대&gt;를 알리는지 아십니까? 판사, 검사, 변호사 모두 이제 “평가”를 받아야 할 때가 왔으니까요. 방청하신 분들을 체감하십니다. 한국의 사법시스템이, 형사재판이, 왜 성폭력 재판이 &lt;피해자…
# 2018-08-17
# 939444369869828096
# RT @ProDogKiumi: 그래도 일본은 맥주가 맛있고 해산물이 맛있고 케이크 기타등등 단간식이 맛있는(중요) 나라라는 이유 하나만으로도 여행하기 충분히 좋은나라같음 깨끗하고 일단 맥주가 맛있고 한국이랑 물가차이도 이제 크게 모르겠는데 맥주가 맛…
# 2018-08-17
# 1002829937370230784
# 백헌아~~ 아이스 자몽 하니 블랙 티가 일본에는 없었다고 ㅠㅠㅠㅠ 마시려면 한국에 가야돼ㅋㅋ어뜨케 ㅋㅋㅋㅋㅋㅋ
# 2018-08-17
# 861013950359457792
# RT @Ssm_kikero: #천창룡엄벌하기2탄#문재인대통령 #김경수경남지사#상습적 #허위사실유포 #명예훼손#정보통신망법위반#제31번째 #피고발인 #천창룡 #서울중앙지검고발 "문재인 대통령을 지키며,국민이 적폐청산에 앞장섭니다"정의로…
# 2018-08-17
# 974279123265667073
# RT @space_sauna: 시원한 바람에 놀란 한국인들 한 2개월 뒤엔 한파에 놀랄것이다
# 2018-08-17
# 804959075372937216
# RT @youthdonation: 박수영 너무 웃기다 진짜 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 한국에 있다가 슬로베니아가서 감탄 중 ㅋㅋㅋㅋㅋㅋㅋㅋ https://t.co/aU2Fc2cEFm

# %% [markdown]
# #### 출처 : https://github.com/ckoepp/TwitterSearch, 방문일 2017년 3월 13일
